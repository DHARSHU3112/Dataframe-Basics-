# %%
import pandas as pd
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Test
# 0                       0.627   50        1  1230
# ...

# %%
d=pd.read_excel("Financial Sample.xlsx")
d
# Out:
#            Segment  Country    Product Discount Band  Units Sold  \
# 0       Government   Canada  Carretera      Very Low      1618.5
# 1       Government  Germany  Carretera      Very Low      1321.0
# 2        Midmarket   France  Carretera      Very Low      2178.0
# 3        Midmarket  Germany  Carretera      Very Low       888.0
# 4        Midmarket   Mexico  Carretera      Very Low      2470.0
# ..             ...      ...        ...           ...         ...
# 731        Private    China        VTT        Medium      1806.0
# 732  Public Sector    India        VTT        Medium      1806.0
# 733  Public Sector    India        VTT        Medium      1806.0
# 734  Public Sector    India        VTT        Medium      1806.0
# 735  Public Sector    India        VTT        Medium      1806.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales  \
# 0                      3          20      32370.0        0.0  32370.0
# ...

# %%
# using Dictionary
weather_data ={
'day':['1/1/2017','1/2/2017','1/3/2017'],
'temperature':[32,35,28],
'windspeed':[6,7,2],
'event':['Rain','Sunny','Snow']
}
k=pd.DataFrame(weather_data)
k
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
# using Dictionary
weather=[
    {'day':'1/1/2017','temperature':32,'windspeed':6,'event':'Rain'},
    {'day':'1/2/2017','temperature':35,'windspeed':7,'event':'Sunny'},
    {'day':'1/3/2017','temperature':28,'windspeed':2,'event':'Snow'}
]
l=pd.DataFrame(weather)
l
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
# using Tuple
salary=[
    (32,'Male','Bachelor degree','Software Engineer',5,90000),
    (28,'Female','Master degree','Data Analyst',3,65000),
    (45,'Male','PhD','Senior Manager',15,150000),
    (36,'Female','Bachelor degree','Sales Associate',7,60000),
    (52,'Male','Master degree','Director',20,200000)
]
m=pd.DataFrame(salary,columns=['Age','Gender','Education','Job Title','Years Of Experience','salary'])
m
# Out:
#    Age  Gender        Education          Job Title  Years Of Experience  \
# 0   32    Male  Bachelor degree  Software Engineer                    5
# 1   28  Female    Master degree       Data Analyst                    3
# 2   45    Male              PhD     Senior Manager                   15
# 3   36  Female  Bachelor degree    Sales Associate                    7
# 4   52    Male    Master degree           Director                   20
#
#    salary
# 0   90000
# 1   65000
# 2  150000
# 3   60000
# 4  200000
